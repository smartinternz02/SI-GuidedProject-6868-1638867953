# %%
#9
seq = ['soup','dog','salad','cat','great']
list(filter(lambda word: word[0]!='s',seq))
# Out:
# ['dog', 'cat', 'great']

# %%
#1
p=pow(7,4)
p
# Out:
# 2401

# %%
#2
sp="Hi there Sam!"
sp.split()
# Out:
# ['Hi', 'there', 'Sam!']

# %%
#3
planet="earth"
diameter=12742
print("The diameter of the {} is {} kilomter.".format(planet,diameter))
# Out:
# The diameter of the earth is 12742 kilomter.

# %%
#4
list=[1,2,[3,4],[5,[100,200,['hello']],23,11],1,7]
list[3][1][2]
# Out:
# ['hello']

# %%
#5
d={'k1':[1,2,3,{'tricky':['oh','man','inception',{'target':[1,2,3,'hello']}]}]} 
print(d['k1'][3]["tricky"][3]['target'][3])
# Out:
# hello

# %%
#6
#tuple:
tuple is a group of dissimallar elements. It is immutable. Tuple supports indexing.
tuple is dem=noted by ()

#list:
contains list of elements.It is mutable. each element or value inside a list is called as an item.
list is denoted by [].

# %%
#7

def domain(email):
    print("your domain is :",email.split('@')[-1])
email= input("please enter your mail: ")
domain(email)
# Out:
# please enter your mail:  abcd@gmail.com
# your domain is : gmail.com

# %%
#8
s=input("Enter your string: >>")

def findDog(s):
    if "dog" in s.lower():
        print("True")
        
    elif "DOG" in s.upper():
        print("True")
        
    else:
        print("False")
        
findDog(s)
# Out:
# Enter your string: >> DOG
# True

# %%
#10
def speed(s):
    if(s<=60):
        print("no Ticket")
    elif(s>=60 and s<81):
        print("small ticket")
    else:
        print("Big Ticket")
sp=int(input("Enter the speed::"))
bi=(input("Is your Birthday or Not(y/n) :: "))

if(bi):
    speed(sp-5)
else:
    speed(sp)
# Out:
# Enter the speed:: 75
# Is your Birthday or Not(y/n) ::  y
# small ticket
